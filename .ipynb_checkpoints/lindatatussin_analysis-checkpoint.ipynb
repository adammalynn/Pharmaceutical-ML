# %% [markdown]
# ### Used method found in the following link:
# https://towardsdatascience.com/how-to-use-machine-learning-for-anomaly-detection-and-condition-monitoring-6742f82900d7

# %%
import pandas as pd
import numpy as np
import os
from sklearn import preprocessing
import seaborn as sns
sns.set(color_codes=True)
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

from numpy.random import seed
from tensorflow import set_random_seed

from keras.layers import Input, Dropout
from keras.layers.core import Dense
from keras.models import Model, Sequential, load_model
from keras import regularizers
from keras.models import model_from_json
# Out:
# Using TensorFlow backend.

# %%
file = 'source_data/lindatatussin_scrubbed.csv'

# %%
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
df.head()
# Out:
#    Sample-Number  Measure F  Measure E  Measure D  Measure C  Measure G  \
# 0          32976        0.3        0.7        9.8        283      0.020
# 1          33045        0.3        0.7        9.9        282      0.020
# 2          33232        0.4        1.1       11.0        282      0.028
# 3          33244        0.1        1.1       10.6        284      0.020
# 4          33392        0.1        1.3       11.7        289      0.021
#
#    Measure B  Measure A  Measure H
# 0       99.6        6.0        140
# 1       99.4        6.1        158
# 2      100.0        6.1        149
# 3       99.9        6.0        157
# 4       99.1        6.1        159

# %%
df.describe()
# Out:
#        Sample-Number   Measure F   Measure E   Measure D   Measure C  \
# count   2.200000e+02  220.000000  220.000000  220.000000  220.000000
# mean    7.877539e+05    0.207273    0.914091   12.291364  278.427273
# std     6.130587e+05    0.094322    0.244635    1.385366   19.706040
# min     3.297600e+04    0.100000    0.400000    8.800000  133.000000
# 25%     2.064330e+05    0.100000    0.775000   11.100000  279.000000
# 50%     7.255275e+05    0.200000    0.900000   12.400000  281.000000
# 75%     1.333909e+06    0.300000    1.000000   13.300000  283.000000
# max     1.895228e+06    0.500000    1.800000   15.600000  300.000000
#
#         Measure G   Measure B   Measure A   Measure H
# count  220.000000  220.000000  220.000000  220.000000
# mean     0.020295   99.738182    6.028636  149.445455
# std      0.003419    0.250655    0.054463    5.967318
# min      0.003000   98.800000    5.800000  140.000000
# 25%      0.019000   99.600000    6.000000  144.000000
# 50%      0.020000   99.800000    6.000000  149.000000
# 75%      0.021000   99.900000    6.100000  155.000000
# max      0.044000  100.000000    6.200000  159.000000

# %%
df_an = df.drop('Sample-Number', axis=1)

# %%
dataset_train = df_an[:96]
dataset_test = df_an[96:]

# %%
dataset_train.plot(figsize = (14,8))
plt.savefig('images/all_measure_traces.png')

# %%
scaler = preprocessing.MinMaxScaler()

X_train = pd.DataFrame(scaler.fit_transform(dataset_train),
                      columns=dataset_train.columns,
                      index=dataset_train.index)

X_test = pd.DataFrame(scaler.transform(dataset_test),
                     columns=dataset_test.columns,
                     index=dataset_test.index)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %% [markdown]
# ## Using autoencoder

# %%
seed(10)
set_random_seed(10)
act_func = 'elu'

# %%
# Input layer:
model=Sequential()
#First hidden layer, connected to input vector X
model.add(Dense(10, activation=act_func,
               kernel_initializer='glorot_uniform',
               kernel_regularizer=regularizers.l2(0.0),
               input_shape=(X_train.shape[1],)
               )
         )
# Out:
# WARNING:tensorflow:From C:\Users\Lenovo\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.add(Dense(2,activation=act_func,
               kernel_initializer='glorot_uniform'))

# %%
model.add(Dense(10,activation=act_func,
               kernel_initializer='glorot_uniform'))

# %%
model.add(Dense(X_train.shape[1],
               kernel_initializer='glorot_uniform'))

# %%
model.compile(loss='mse', optimizer='adam')

# Train the model
NUM_EPOCHS = 100
BATCH_SIZE = 10

# %%
history=model.fit(np.array(X_train), np.array(X_train),
                 batch_size=BATCH_SIZE,
                 epochs=NUM_EPOCHS,
                 validation_split=0.05,
                 verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\Lenovo\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 91 samples, validate on 5 samples
# Epoch 1/100
# 91/91 [==============================] - 0s 4ms/step - loss: 0.4351 - val_loss: 0.3516
# Epoch 2/100
# 91/91 [==============================] - 0s 132us/step - loss: 0.3617 - val_loss: 0.2969
# Epoch 3/100
# 91/91 [==============================] - 0s 132us/step - loss: 0.3018 - val_loss: 0.2509
# Epoch 4/100
# 91/91 [==============================] - 0s 154us/step - loss: 0.2526 - val_loss: 0.2152
# Epoch 5/100
# 91/91 [==============================] - 0s 154us/step - loss: 0.2135 - val_loss: 0.1851
# Epoch 6/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.1820 - val_loss: 0.1597
# Epoch 7/100
# 91/91 [==============================] - 0s 143us/step - loss: 0.1555 - val_loss: 0.1353
# Epoch 8/100
# 91/91 [==============================] - 0s 143us/step - loss: 0.1338 - val_loss: 0.1164
# Epoch 9/100
# 91/91 [==============================] - 0s 154us/step - loss: 0.1146 - val_loss: 0.1014
# Epoch 10/100
# 91/91 [==============================] - 0s 154us/step - loss: 0.0995 - val_loss: 0.0878
# Epoch 11/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.0870 - val_loss: 0.0751
# Epoch 12/100
# 91/91 [==============================] - 0s 143us/step - loss: 0.0769 - val_loss: 0.0658
# Epoch 13/100
# 91/91 [==============================] - 0s 165us/step - loss: 0.0691 - val_loss: 0.0593
# Epoch 14/100
# 91/91 [==============================] - 0s 132us/step - loss: 0.0633 - val_loss: 0.0543
# Epoch 15/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.0587 - val_loss: 0.0506
# Epoch 16/100
# 91/91 [==============================] - 0s 132us/step - loss: 0.0553 - val_loss: 0.0472
# Epoch 17/100
# 91/91 [==============================] - 0s 165us/step - loss: 0.0527 - val_loss: 0.0453
# Epoch 18/100
# 91/91 [==============================] - 0s 143us/step - loss: 0.0508 - val_loss: 0.0437
# Epoch 19/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.0494 - val_loss: 0.0418
# Epoch 20/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.0482 - val_loss: 0.0411
# Epoch 21/100
# 91/91 [==============================] - 0s 132us/step - loss: 0.0471 - val_loss: 0.0406
# Epoch 22/100
# 91/91 [==============================] - 0s 143us/step - loss: 0.0463 - val_loss: 0.0400
# Epoch 23/100
# 91/91 [==============================] - 0s 165us/step - loss: 0.0452 - val_loss: 0.0387
# Epoch 24/100
# 91/91 [==============================] - 0s 143us/step - loss: 0.0446 - val_loss: 0.0385
# Epoch 25/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.0440 - val_loss: 0.0386
# Epoch 26/100
# 91/91 [==============================] - 0s 165us/step - loss: 0.0435 - val_loss: 0.0385
# Epoch 27/100
# 91/91 [==============================] - 0s 154us/step - loss: 0.0429 - val_loss: 0.0373
# Epoch 28/100
# 91/91 [==============================] - 0s 165us/step - loss: 0.0426 - val_loss: 0.0362
# Epoch 29/100
# 91/91 [==============================] - 0s 231us/step - loss: 0.0421 - val_loss: 0.0355
# Epoch 30/100
# 91/91 [==============================] - 0s 220us/step - loss: 0.0418 - val_loss: 0.0356
# Epoch 31/100
# 91/91 [==============================] - 0s 286us/step - loss: 0.0414 - val_loss: 0.0351
# Epoch 32/100
# 91/91 [==============================] - 0s 209us/step - loss: 0.0410 - val_loss: 0.0346
# Epoch 33/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.0407 - val_loss: 0.0349
# Epoch 34/100
# 91/91 [==============================] - 0s 187us/step - loss: 0.0403 - val_loss: 0.0348
# Epoch 35/100
# 91/91 [==============================] - 0s 143us/step - loss: 0.0400 - val_loss: 0.0342
# Epoch 36/100
# 91/91 [==============================] - 0s 165us/step - loss: 0.0397 - val_loss: 0.0347
# Epoch 37/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.0396 - val_loss: 0.0347
# Epoch 38/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.0392 - val_loss: 0.0336
# Epoch 39/100
# 91/91 [==============================] - 0s 154us/step - loss: 0.0389 - val_loss: 0.0336
# Epoch 40/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.0387 - val_loss: 0.0337
# Epoch 41/100
# 91/91 [==============================] - 0s 154us/step - loss: 0.0384 - val_loss: 0.0333
# Epoch 42/100
# 91/91 [==============================] - 0s 143us/step - loss: 0.0382 - val_loss: 0.0332
# Epoch 43/100
# 91/91 [==============================] - 0s 209us/step - loss: 0.0380 - val_loss: 0.0335
# Epoch 44/100
# 91/91 [==============================] - 0s 143us/step - loss: 0.0378 - val_loss: 0.0331
# Epoch 45/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.0376 - val_loss: 0.0329
# Epoch 46/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.0374 - val_loss: 0.0326
# Epoch 47/100
# 91/91 [==============================] - 0s 132us/step - loss: 0.0373 - val_loss: 0.0321
# Epoch 48/100
# 91/91 [==============================] - 0s 165us/step - loss: 0.0371 - val_loss: 0.0318
# Epoch 49/100
# 91/91 [==============================] - 0s 121us/step - loss: 0.0368 - val_loss: 0.0318
# Epoch 50/100
# 91/91 [==============================] - 0s 187us/step - loss: 0.0366 - val_loss: 0.0311
# Epoch 51/100
# 91/91 [==============================] - 0s 143us/step - loss: 0.0364 - val_loss: 0.0310
# Epoch 52/100
# 91/91 [==============================] - 0s 165us/step - loss: 0.0362 - val_loss: 0.0316
# Epoch 53/100
# 91/91 [==============================] - 0s 187us/step - loss: 0.0360 - val_loss: 0.0317
# Epoch 54/100
# 91/91 [==============================] - 0s 132us/step - loss: 0.0358 - val_loss: 0.0311
# Epoch 55/100
# 91/91 [==============================] - 0s 154us/step - loss: 0.0355 - val_loss: 0.0311
# Epoch 56/100
# 91/91 [==============================] - 0s 154us/step - loss: 0.0354 - val_loss: 0.0305
# Epoch 57/100
# 91/91 [==============================] - 0s 132us/step - loss: 0.0352 - val_loss: 0.0303
# Epoch 58/100
# 91/91 [==============================] - 0s 154us/step - loss: 0.0351 - val_loss: 0.0301
# Epoch 59/100
# 91/91 [==============================] - 0s 143us/step - loss: 0.0351 - val_loss: 0.0302
# Epoch 60/100
# 91/91 [==============================] - 0s 187us/step - loss: 0.0349 - val_loss: 0.0304
# Epoch 61/100
# 91/91 [==============================] - 0s 154us/step - loss: 0.0347 - val_loss: 0.0306
# Epoch 62/100
# 91/91 [==============================] - 0s 154us/step - loss: 0.0344 - val_loss: 0.0303
# Epoch 63/100
# 91/91 [==============================] - 0s 132us/step - loss: 0.0343 - val_loss: 0.0301
# Epoch 64/100
# 91/91 [==============================] - 0s 187us/step - loss: 0.0342 - val_loss: 0.0298
# Epoch 65/100
# 91/91 [==============================] - 0s 132us/step - loss: 0.0340 - val_loss: 0.0301
# Epoch 66/100
# 91/91 [==============================] - 0s 165us/step - loss: 0.0338 - val_loss: 0.0306
# Epoch 67/100
# 91/91 [==============================] - 0s 143us/step - loss: 0.0337 - val_loss: 0.0304
# Epoch 68/100
# 91/91 [==============================] - 0s 165us/step - loss: 0.0336 - val_loss: 0.0300
# Epoch 69/100
# 91/91 [==============================] - 0s 209us/step - loss: 0.0335 - val_loss: 0.0296
# Epoch 70/100
# 91/91 [==============================] - 0s 275us/step - loss: 0.0334 - val_loss: 0.0292
# Epoch 71/100
# 91/91 [==============================] - 0s 187us/step - loss: 0.0333 - val_loss: 0.0292
# Epoch 72/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.0331 - val_loss: 0.0291
# Epoch 73/100
# 91/91 [==============================] - 0s 231us/step - loss: 0.0331 - val_loss: 0.0287
# Epoch 74/100
# 91/91 [==============================] - 0s 198us/step - loss: 0.0330 - val_loss: 0.0283
# Epoch 75/100
# 91/91 [==============================] - 0s 187us/step - loss: 0.0328 - val_loss: 0.0289
# Epoch 76/100
# 91/91 [==============================] - 0s 165us/step - loss: 0.0327 - val_loss: 0.0297
# Epoch 77/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.0326 - val_loss: 0.0297
# Epoch 78/100
# 91/91 [==============================] - 0s 187us/step - loss: 0.0325 - val_loss: 0.0302
# Epoch 79/100
# 91/91 [==============================] - 0s 198us/step - loss: 0.0325 - val_loss: 0.0297
# Epoch 80/100
# 91/91 [==============================] - 0s 209us/step - loss: 0.0323 - val_loss: 0.0293
# Epoch 81/100
# 91/91 [==============================] - 0s 165us/step - loss: 0.0322 - val_loss: 0.0289
# Epoch 82/100
# 91/91 [==============================] - 0s 187us/step - loss: 0.0323 - val_loss: 0.0286
# Epoch 83/100
# 91/91 [==============================] - 0s 198us/step - loss: 0.0320 - val_loss: 0.0285
# Epoch 84/100
# 91/91 [==============================] - 0s 231us/step - loss: 0.0319 - val_loss: 0.0285
# Epoch 85/100
# 91/91 [==============================] - ETA: 0s - loss: 0.029 - 0s 198us/step - loss: 0.0318 - val_loss: 0.0286
# Epoch 86/100
# 91/91 [==============================] - 0s 253us/step - loss: 0.0318 - val_loss: 0.0285
# Epoch 87/100
# 91/91 [==============================] - 0s 209us/step - loss: 0.0317 - val_loss: 0.0286
# Epoch 88/100
# 91/91 [==============================] - 0s 176us/step - loss: 0.0317 - val_loss: 0.0277
# Epoch 89/100
# 91/91 [==============================] - 0s 231us/step - loss: 0.0316 - val_loss: 0.0275
# Epoch 90/100
# 91/91 [==============================] - 0s 187us/step - loss: 0.0315 - val_loss: 0.0275
# Epoch 91/100
# 91/91 [==============================] - 0s 198us/step - loss: 0.0314 - val_loss: 0.0279
# Epoch 92/100
# 91/91 [==============================] - 0s 286us/step - loss: 0.0313 - val_loss: 0.0280
# Epoch 93/100
# 91/91 [==============================] - 0s 198us/step - loss: 0.0312 - val_loss: 0.0281
# Epoch 94/100
# 91/91 [==============================] - 0s 187us/step - loss: 0.0311 - val_loss: 0.0276
# Epoch 95/100
# 91/91 [==============================] - 0s 220us/step - loss: 0.0311 - val_loss: 0.0274
# Epoch 96/100
# 91/91 [==============================] - 0s 187us/step - loss: 0.0311 - val_loss: 0.0278
# Epoch 97/100
# 91/91 [==============================] - 0s 165us/step - loss: 0.0310 - val_loss: 0.0275
# Epoch 98/100
# 91/91 [==============================] - 0s 231us/step - loss: 0.0309 - val_loss: 0.0281
# Epoch 99/100
# 91/91 [==============================] - 0s 209us/step - loss: 0.0309 - val_loss: 0.0280
# Epoch 100/100
# 91/91 [==============================] - 0s 165us/step - loss: 0.0308 - val_loss: 0.0276

# %%
mpl.rcParams['figure.figsize'] = [14,8]
plt.plot(history.history['loss'],
        'b',
        label='Training Loss')
plt.plot(history.history['val_loss'],
        'r',
        label='Validation loss')
plt.legend(loc='upper right')
plt.xlabel('Epochs')
plt.ylabel('Loss, [mse]')
plt.ylim([0,.1])
plt.plot(figsize = (14,8))
plt.savefig('images/training_val_loss.png')
plt.show()

# %%
X_pred = model.predict(np.array(X_train))
X_pred = pd.DataFrame(X_pred, columns=X_train.columns)

X_pred.index = X_train.index

scored = pd.DataFrame(index=X_train.index)

scored['Loss_mae'] = np.mean(np.abs(X_pred-X_train), axis = 1)
plt.figure()
sns.distplot(scored['Loss_mae'],
             bins = 10, 
             kde= True,
            color = 'green');
plt.xlim([0.0,.5])
plt.savefig('images/loss_distribution.png')
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Will use a threshold of 0.35

# %%
X_pred = model.predict(np.array(X_test))
X_pred = pd.DataFrame(X_pred, 
                      columns=X_test.columns)
X_pred.index = X_test.index

scored = pd.DataFrame(index=X_test.index)
scored['Loss_mae'] = np.mean(np.abs(X_pred-X_test), axis = 1)
scored['Threshold'] = 0.35
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()
# Out:
#      Loss_mae  Threshold  Anomaly
# 96   0.294635       0.35    False
# 97   2.554656       0.35     True
# 98   0.133500       0.35    False
# 99   0.103381       0.35    False
# 100  0.180907       0.35    False

# %%
X_pred_train = model.predict(np.array(X_train))
X_pred_train = pd.DataFrame(X_pred_train, 
                      columns=X_train.columns)
X_pred_train.index = X_train.index

scored_train = pd.DataFrame(index=X_train.index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-X_train), axis = 1)
scored_train['Threshold'] = 0.35
scored_train['Anomaly'] = scored_train['Loss_mae'] > scored_train['Threshold']

# %%
scored = pd.concat([scored_train, scored])
scored.head()
# Out:
#    Loss_mae  Threshold  Anomaly
# 0  0.083839       0.35    False
# 1  0.202714       0.35    False
# 2  0.238062       0.35    False
# 3  0.174024       0.35    False
# 4  0.367026       0.35     True

# %%
scored.plot(logy=True,  figsize = (12,8), ylim = [1e-2,1e1], color = ['#0099ff','#ff6600'])
plt.savefig('images/loss_threshold_all.png')

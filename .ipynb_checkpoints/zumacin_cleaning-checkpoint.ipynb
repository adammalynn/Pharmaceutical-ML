# %%
# Dependencies
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from datetime import datetime

# %%
#import csv file
file = 'source_data/zumacin_scrubbed.csv'

# %%
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
df.head()
# Out:
#    SAMPLE_NUMBER  Assay Date  Compartment Temp Reagent-A ID  \
# 0         120629  01/28/2011               4.9  11-001-0014
# 1         126733  02/15/2011               4.9      11R0834
# 2         134380  03/04/2011               5.2  11-001-0014
# 3         140369  03/23/2011               4.9      11R1229
# 4         142003         NaN               NaN          NaN
#
#   Reagent-A ID Exp Date Reagent-B Exp Date Reagent-B ID Material-A ID  \
# 0            04/25/2011                NaN          NaN     R5307-19P
# 1            05/12/2011         02/23/2011      11R1008     P5530-19N
# 2            04/25/2011                NaN          NaN     R6269-22P
# 3            06/14/2011         03/30/2011      11R0847     P5530-19N
# 4                   NaN                NaN          NaN           NaN
#
#   Reagent-C Lot Reagent-D Lot Reagent-E Lot  Reagent-F Concentration  \
# 0           NaN           NaN       10R1856                      NaN
# ...

# %%
df.dtypes
# Out:
# SAMPLE_NUMBER                int64
# Assay Date                  object
# Compartment Temp           float64
# Reagent-A ID                object
# Reagent-A ID Exp Date       object
# Reagent-B Exp Date          object
# Reagent-B ID                object
# Material-A ID               object
# Reagent-C Lot               object
# Reagent-D Lot               object
# Reagent-E Lot               object
# Reagent-F Concentration    float64
# Reagent-F Expiration        object
# Reagent-F Lot               object
# SOP Version                float64
# Agg%                       float64
# INSTRUMENT                 float64
# Main%                      float64
# Lab_Site                    object
# Chemist                     object
# dtype: object

# %%
uniques = df['Reagent-A ID'].unique()
uniques
# Out:
# array(['11-001-0014', '11R0834', '11R1229', nan, '11-002-0098',
#        '11-004-0089', '11R1271', '11-015-0052', '11-012-0044',
#        '11-014-0076', '11-016-0061', '11-014-0118', '11-015-0154',
#        '11-016-0112', '11-015-0173', '11R0394', '11R1612', '11R1625',
#        '11-012-0190', '11R1468', '12-001-0005', '12-001-0040',
#        '12-003-0044', '12-004-0059', '12-001-0119', '12-001-0126',
#        '12-001-0148', '12-005-0101', '12-001-0186', '12-001-0197',
#        '12-005-0135', '12-001-0197 and SB-12-005-0135', '12R1414',
#        '12-018-0040', '12-021-0078', '12-018-0107', '12-019-0086',
#        '12-019-0117', '12-019-0086/ SB-12-019-0117', '12-019-0149',
#        '12-021-0193', '12-019-0191', '13-009-0027', '13-008-0027',
#        '13R1069', '13R0020', '12-019-0191, SB-13-008-0027', '13-007-0063',
#        '13R1514', ' assay comments', '13-007-0109', '13-009-0141',
#        '13-008-0108', '13-008-0124', '13-008-0131', '13-008-0143',
# ...

# %%
newArr = ['hello',4,'bye',uniques[3]]
for counter,item in enumerate(newArr, 0):
    if([item] != [np.nan]):
        print(item, counter)
# Out:
# hello 0
# 4 1
# bye 2

# %%
replaceDict = {#'Reagent-A ID': 'ReagentA',
              'Reagent-B ID': 'ReagentB',
              'Material-A ID': 'MaterialA',
               'Reagent-C Lot': 'ReagentC',
               'Reagent-D Lot': 'ReagentD',
               'Reagent-E Lot': 'ReagentE',
               'Reagent-F Lot': 'ReagentF',
               }

# %%
theArr = [1,2,'NaN',4,5]
for counter,item in enumerate(theArr, 1):
    if(co)
    print(item, counter)
# Out:
# 1 1
# 2 2
# NaN 3
# 4 4
# 5 5

# %%
random.randint(0,1000)
# Out:
# 270

# %%
#DataFrame.replace(to_replace=None, value=None, inplace=False, limit=None, regex=False, method='pad')[source]

# %%
def maskCol(col):
    
    replace_arr = df[col].unique()
    for counter,item in enumerate(replace_arr, 1):
        if([item] != [np.nan]):
            newNum = f"{replaceDict[col]}-{counter}-{random.randint(0,1000)}"
            df.replace(to_replace=item,value=newNum, inplace=True)           
               
    #for range 1 to 183
    ##

# %%
for name in replaceDict:
    maskCol(name)

# %%
maskCol('Reagent-A ID')

# %%
df[ 'Reagent-F Lot'].unique()
# Out:
# array(['ReagentF-1-779', nan, 'ReagentF-3-623', 'ReagentF-4-825'],
#       dtype=object)

# %%
df['Agg%'] = df['Agg%'] * 1.02

# %%
df['Main%'] = df['Main%'] * 0.98

# %%
df['SOP Version'] = df['SOP Version'] + 1.6

# %%
df['INSTRUMENT'] = df['INSTRUMENT'] + 3.0

# %%
df['Compartment Temp'] = df['Compartment Temp'] - 0.3

# %%
df.head()
# Out:
#    SAMPLE_NUMBER  Assay Date  Compartment Temp    Reagent-A ID  \
# 0         120629  01/28/2011               4.3   ReagentA-1-32
# 1         126733  02/15/2011               4.3  ReagentA-2-654
# 2         134380  03/04/2011               4.6   ReagentA-1-32
# 3         140369  03/23/2011               4.3  ReagentA-3-383
# 4         142003         NaN               NaN             NaN
#
#   Reagent-A ID Exp Date Reagent-B Exp Date    Reagent-B ID    Material-A ID  \
# 0            04/25/2011                NaN             NaN  MaterialA-1-554
# 1            05/12/2011         02/23/2011  ReagentB-2-867   MaterialA-2-47
# 2            04/25/2011                NaN             NaN  MaterialA-3-451
# 3            06/14/2011         03/30/2011  ReagentB-3-584   MaterialA-2-47
# 4                   NaN                NaN             NaN              NaN
#
#   Reagent-C Lot Reagent-D Lot   Reagent-E Lot  Reagent-F Concentration  \
# ...

# %%
df.count()
# Out:
# SAMPLE_NUMBER              435
# Assay Date                 422
# Compartment Temp           404
# Reagent-A ID               419
# Reagent-A ID Exp Date      419
# Reagent-B Exp Date          17
# Reagent-B ID                17
# Material-A ID              415
# Reagent-C Lot              118
# Reagent-D Lot              407
# Reagent-E Lot              408
# Reagent-F Concentration    405
# Reagent-F Expiration       416
# Reagent-F Lot              416
# SOP Version                421
# Agg%                       361
# INSTRUMENT                 420
# Main%                      366
# Lab_Site                   430
# Chemist                    422
# dtype: int64

# %%
#drop Reagent-B Exp Date/B ID and Reagent-C Lot
df.drop(['Reagent-B Exp Date', 'Reagent-B ID', 'Reagent-C Lot'], axis=1)
# Out:
#      SAMPLE_NUMBER  Assay Date  Compartment Temp        Reagent-A ID  \
# 0           120629  01/28/2011               4.9         11-001-0014
# 1           126733  02/15/2011               4.9             11R0834
# 2           134380  03/04/2011               5.2         11-001-0014
# 3           140369  03/23/2011               4.9             11R1229
# 4           142003         NaN               NaN                 NaN
# 5           142895  03/30/2011               NaN         11-001-0014
# 6           150741  04/19/2011               4.9         11-002-0098
# 7           150958  04/20/2011               4.9         11-002-0098
# 8           158404  05/09/2011               5.2         11-004-0089
# 9           166625  05/27/2011               4.9         11-004-0089
# 10          171505  06/08/2011               4.9         11-004-0089
# 11          172363         NaN               NaN                 NaN
# 12          172367         NaN               NaN                 NaN
# ...

# %%
# Drop null data in the Assay Column
clean_zumacin = df.dropna(subset=['Assay Date'])

# %%
#replace null value with zero
# clean_zumacin=df.fillna(value=0)

# %%
# #rename the column
clean_zumacin.rename(columns={"Assay Date":"Assay_Date"}, inplace=True)
clean_zumacin.rename(columns={"Compartment Temp":"Compartment_Temp"}, inplace=True)
clean_zumacin.rename(columns={"Reagent-A ID Exp Date":"Reagent-A_ID_Exp_Date"}, inplace=True)
clean_zumacin.rename(columns={"Reagent-B Exp Date":"Reagent-B_Exp_Date"}, inplace=True)
clean_zumacin.rename(columns={"Reagent-F Expiration":"Reagent-F_Expiration"}, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
clean_zumacin.head()
# Out:
#    SAMPLE_NUMBER  Assay_Date  Compartment_Temp Reagent-A ID  \
# 0         120629  01/28/2011               4.9  11-001-0014
# 1         126733  02/15/2011               4.9      11R0834
# 2         134380  03/04/2011               5.2  11-001-0014
# 3         140369  03/23/2011               4.9      11R1229
# 5         142895  03/30/2011               NaN  11-001-0014
#
#   Reagent-A_ID_Exp_Date Reagent-B_Exp_Date Reagent-B ID Material-A ID  \
# 0            04/25/2011                NaN          NaN     R5307-19P
# 1            05/12/2011         02/23/2011      11R1008     P5530-19N
# 2            04/25/2011                NaN          NaN     R6269-22P
# 3            06/14/2011         03/30/2011      11R0847     P5530-19N
# 5            04/25/2011                NaN          NaN     R6284-22P
#
#   Reagent-C Lot Reagent-D Lot Reagent-E Lot  Reagent-F Concentration  \
# 0           NaN           NaN       10R1856                      NaN
# ...

# %%
clean_zumacin.dtypes
# Out:
# SAMPLE_NUMBER                int64
# Assay_Date                  object
# Compartment_Temp           float64
# Reagent-A ID                object
# Reagent-A_ID_Exp_Date       object
# Reagent-B_Exp_Date          object
# Reagent-B ID                object
# Material-A ID               object
# Reagent-C Lot               object
# Reagent-D Lot               object
# Reagent-E Lot               object
# Reagent-F Concentration    float64
# Reagent-F_Expiration        object
# Reagent-F Lot               object
# SOP Version                float64
# Agg%                       float64
# INSTRUMENT                 float64
# Main%                      float64
# Lab_Site                    object
# Chemist                     object
# dtype: object

# %%
clean_zumacin.count()
# Out:
# SAMPLE_NUMBER              422
# Assay_Date                 422
# Compartment_Temp           404
# Reagent-A ID               419
# Reagent-A_ID_Exp_Date      419
# Reagent-B_Exp_Date          17
# Reagent-B ID                17
# Material-A ID              415
# Reagent-C Lot              116
# Reagent-D Lot              407
# Reagent-E Lot              408
# Reagent-F Concentration    405
# Reagent-F_Expiration       416
# Reagent-F Lot              416
# SOP Version                421
# Agg%                       361
# INSTRUMENT                 420
# Main%                      366
# Lab_Site                   422
# Chemist                    422
# dtype: int64

# %%
# # #convert to assay date to float
# clean_zumacin['Assay_Date'] = clean_zumacin.Assay_Date.astype(float)
# # df_all_reagents.dtypes

# %%
# df_all_reagents["Assay Date"] = pd.to_string(df_all_reagents["Assay Date"])
# df_all_reagents['Assay Date'] = df_all_reagents['Assay Date'].astype(str)
# df_all_reagents.dtypes

# %%
# df_all_reagents['Assay Date'] = df_all_reagents['Assay Date'].astype(str)
# df_all_reagents.dtypes
# df_all_reagents = datetime.strptime(df_all_reagents, '%m/%d/%y')
# df_all_reagents.dtypes

# %%
#date opbject to date time
clean_zumacin["Assay_Date"] = pd.to_datetime(clean_zumacin["Assay_Date"])
# clean_zumacin["Reagent-A_ID_Exp_Date"] = pd.to_datetime(clean_zumacin["Reagent-A_ID_Exp_Date"])
# clean_zumacin["Reagent-B_Exp_Date"] = pd.to_datetime(clean_zumacin["Reagent-B_Exp_Date"])
# clean_zumacin["Reagent-F_Expiration"] = pd.to_datetime(clean_zumacin["Reagent-F_Expiration"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
clean_zumacin.dtypes
# Out:
# SAMPLE_NUMBER                       int64
# Assay_Date                 datetime64[ns]
# Compartment_Temp                  float64
# Reagent-A ID                       object
# Reagent-A_ID_Exp_Date              object
# Reagent-B_Exp_Date                 object
# Reagent-B ID                       object
# Material-A ID                      object
# Reagent-C Lot                      object
# Reagent-D Lot                      object
# Reagent-E Lot                      object
# Reagent-F Concentration           float64
# Reagent-F_Expiration               object
# Reagent-F Lot                      object
# SOP Version                       float64
# Agg%                              float64
# INSTRUMENT                        float64
# Main%                             float64
# Lab_Site                           object
# Chemist                            object
# dtype: object

# %%
clean_zumacin.to_csv("Output/clean_zumacin.csv", index=False, header=True)

# %%
# df_all_reagents.head()

# %%
# assayDate=df_all_reagents.iloc[:,1]
# print(assayDate)

# %%
# # Assign the data to X and y
# # Note: Sklearn requires a two-dimensional array of values
# # so we use reshape to create this
# X = df_all_reagents['Assay Date'].values.reshape(-1, 1)
# y = df_all_reagents['Agg%'].values.reshape(-1, 1)

# print( X, y)

# %%
# # Create the model and fit the model to the data

# from sklearn.linear_model import LinearRegression

# ### BEGIN SOLUTION

# model = LinearRegression()

# ### END SOLUTION

# %%
# # Fit the model to the data.
# # Note: This is the training step where you fit the line to the data.

# ### BEGIN SOLUTION

# model.fit(X, y)

# ### END SOLUTION

# %%
# print('Weight coefficients: ', model.coef_)
# print('y-axis intercept: ', model.intercept_)

# %%
# # Note: we have to transform our min and max values
# # so they are in the format: array([[ 1.17]])
# # This is the required format for `model.predict()`

# y_min = np.array([[y.min()]])
# y_max = np.array([[y.max()]])
# print(f"Min y Value: {y_min}")
# print(f"Max y Value: {y_max}")

# %%
# # Calculate the y_min and y_max using model.predict and x_min and x_max

# ### BEGIN SOLUTION
# x_min = model.predict(y_min)
# x_max = model.predict(y_max)
# ### END SOLUTION

# %%
# # Plot X and y using plt.scatter
# # Plot the model fit line using [x_min[0], x_max[0]], [y_min[0], y_max[0]]

# ### BEGIN SOLUTION
# plt.scatter(X, y, c='blue')
# plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
# ### END SOLUTION

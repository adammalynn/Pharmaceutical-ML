# %%
# Import Dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame
df = pd.read_csv('Output/lumid_5c.csv')
df.head()
# Out:
#    TIMEPOINT         NAME  ENTRY CONDITION PRODUCT  Sample-Number    Lot
# 0          6  Deamidation   3.50        5C   Lumab          21573  39360
# 1          9  Deamidation   3.30        5C   Lumab          21575  39360
# 2         12  Deamidation   4.30        5C   Lumab          21578  39360
# 3         24  Deamidation   3.64        5C   Lumab          95206  39404
# 4         24  Deamidation   3.99        5C   Lumab          95209  39408

# %%
# Establish the bins 
entry_bins = [0, 1.3, 2.3, 3.3, 4.3, 5.3, 6.3, 7.3]
group_names = ["1.3", "2.3", "3.3", "4.3", "5.3", "6.3", "7.3"]

# Categorize the deamidiation measurement using entry_bins
df["entry_range"] = pd.cut(df["ENTRY"], entry_bins, labels=group_names)

df.head()
# Out:
#    TIMEPOINT         NAME  ENTRY CONDITION PRODUCT  Sample-Number    Lot  \
# 0          6  Deamidation   3.50        5C   Lumab          21573  39360
# 1          9  Deamidation   3.30        5C   Lumab          21575  39360
# 2         12  Deamidation   4.30        5C   Lumab          21578  39360
# 3         24  Deamidation   3.64        5C   Lumab          95206  39404
# 4         24  Deamidation   3.99        5C   Lumab          95209  39408
#
#   entry_range
# 0         4.3
# 1         3.3
# 2         4.3
# 3         4.3
# 4         4.3

# %%
#df = df.loc[df["entry_range"] > "3.3" , :]

# %% [markdown]
# #

# %%
df
# Out:
#      TIMEPOINT         NAME  ENTRY CONDITION PRODUCT  Sample-Number    Lot  \
# 0            6  Deamidation   3.50        5C   Lumab          21573  39360
# 1            9  Deamidation   3.30        5C   Lumab          21575  39360
# 2           12  Deamidation   4.30        5C   Lumab          21578  39360
# 3           24  Deamidation   3.64        5C   Lumab          95206  39404
# 4           24  Deamidation   3.99        5C   Lumab          95209  39408
# 5            5  Deamidation   4.50        5C   Lumab         127889  39511
# 6           38  Deamidation   6.90        5C   Lumab         127890  39346
# 7           31  Deamidation   4.70        5C   Lumab         124962  39360
# 8           31  Deamidation   3.90        5C   Lumab         124963  39365
# 9            9  Deamidation   4.72        5C   Lumab         131358  39499
# 10          36  Deamidation   5.04        5C   Lumab         131361  42485
# 11          18  Deamidation   5.13        5C   Lumab         136770  39465
# 12          38  Deamidation   6.10        5C   Lumab         136771  39352
# 13          38  Deamidation   5.20        5C   Lumab         221597  39360
# 14          38  Deamidation   4.70        5C   Lumab         221598  39362
# 15          30  Deamidation   6.32        5C   Lumab         232577  42487
# 16          36  Deamidation   6.30        5C   Lumab         248179  39408
# 17          36  Deamidation   5.98        5C   Lumab         248051  39404
# 18           9  Deamidation   4.61        5C   Lumab         258775  39551
# 19           9  Deamidation   4.22        5C   Lumab         258778  39557
# 20          30  Deamidation   5.87        5C   Lumab          18407  42483
# 21          30  Deamidation   6.70        5C   Lumab          32794  39346
# 22          30  Deamidation   5.62        5C   Lumab          32796  39347
# 23           6  Deamidation   4.54        5C   Lumab         120351  39511
# 24           3  Deamidation   3.07        5C   Lumab         120354  39529
# 25           6  Deamidation   3.03        5C   Lumab         217234  39557
# 26           6  Deamidation   4.31        5C   Lumab         217237  39551
# 27          24  Deamidation   5.13        5C   Lumab         220057  39465
# 28          12  Deamidation   4.73        5C   Lumab         238587  39529
# 29          12  Deamidation   6.52        5C   Lumab         238587  39529
# ..         ...          ...    ...       ...     ...            ...    ...
# 180         37  Deamidation   5.91        5C   Lumab          86307  42483
# 181         36  Deamidation   7.00        5C   Lumab          97699  39351
# 182         36  Deamidation   6.07        5C   Lumab          97702  39352
# 183          6  Deamidation   3.08        5C   Lumab          97375  39499
# 184         24  Deamidation   4.46        5C   Lumab         177177  39445
# 185          3  Deamidation   3.58        5C   Lumab         176156  39551
# 186          3  Deamidation   3.00        5C   Lumab         176157  39557
# 187          4  Deamidation   3.60        5C   Lumab         198812  39551
# 188          0  Deamidation   3.30        5C   Lumab         198814  39551
# 189          0  Deamidation   3.30        5C   Lumab         198817  39557
# 190          0  Deamidation   3.50        5C   Lumab         286067  39590
# 191          6  Deamidation   6.10        5C   Lumab         286068  39590
# 192          6  Deamidation   6.60        5C   Lumab         286068  39590
# 193          0  Deamidation   4.70        5C   Lumab         289410  39569
# 194          9  Deamidation   7.14        5C   Lumab         289411  39569
# 195          9  Deamidation   4.79        5C   Lumab          22941  39445
# 196          6  Deamidation   4.32        5C   Lumab          22943  39465
# 197          0  Deamidation   3.30        5C   Lumab          24563  39362
# 198          3  Deamidation   3.30        5C   Lumab          24566  39362
# 199          6  Deamidation   3.70        5C   Lumab          24569  39362
# 200          9  Deamidation   4.00        5C   Lumab          24572  39362
# 201         12  Deamidation   4.40        5C   Lumab          24578  39362
# 202         18  Deamidation   4.48        5C   Lumab          82036  42487
# 203         12  Deamidation   4.56        5C   Lumab         171269  39499
# 204         36  Deamidation   5.22        5C   Lumab         176613  39360
# 205         36  Deamidation   3.99        5C   Lumab         176619  39365
# 206         18  Deamidation   5.20        5C   Lumab         286069  39511
# 207         24  Deamidation   4.26        5C   Lumab         154843  42487
# 208         18  Deamidation   4.83        5C   Lumab         251852  39499
# 209         30  Deamidation   4.77        5C   Lumab         262167  39445
#
#     entry_range
# 0           4.3
# 1           3.3
# 2           4.3
# 3           4.3
# 4           4.3
# 5           5.3
# 6           7.3
# 7           5.3
# 8           4.3
# 9           5.3
# 10          5.3
# 11          5.3
# 12          6.3
# 13          5.3
# 14          5.3
# 15          7.3
# 16          6.3
# 17          6.3
# 18          5.3
# 19          4.3
# 20          6.3
# 21          7.3
# 22          6.3
# 23          5.3
# 24          3.3
# 25          3.3
# 26          5.3
# 27          5.3
# 28          5.3
# 29          7.3
# ..          ...
# 180         6.3
# 181         7.3
# 182         6.3
# 183         3.3
# 184         5.3
# 185         4.3
# 186         3.3
# 187         4.3
# 188         3.3
# 189         3.3
# 190         4.3
# 191         6.3
# 192         7.3
# 193         5.3
# 194         7.3
# 195         5.3
# 196         5.3
# 197         3.3
# 198         3.3
# 199         4.3
# 200         4.3
# 201         5.3
# 202         5.3
# 203         5.3
# 204         5.3
# 205         4.3
# 206         5.3
# 207         4.3
# 208         5.3
# 209         5.3
#
# [210 rows x 8 columns]

# %%
# correlation test of the dataset
test=df.corr()

# %%
test
# Out:
#                TIMEPOINT     ENTRY  Sample-Number       Lot
# TIMEPOINT       1.000000  0.648855       0.163828  0.045198
# ENTRY           0.648855  1.000000       0.062092 -0.176274
# Sample-Number   0.163828  0.062092       1.000000  0.241585
# Lot             0.045198 -0.176274       0.241585  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(test)
# Save Figure
plt.savefig("images/heat_map.png")

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

X = df.TIMEPOINT.values.reshape(-1, 1)
y = df.ENTRY.values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
X
# Out:
# Shape:  (210, 1) (210, 1)
# array([[ 6],
#        [ 9],
#        [12],
#        [24],
#        [24],
#        [ 5],
#        [38],
#        [31],
#        [31],
#        [ 9],
#        [36],
#        [18],
#        [38],
#        [38],
#        [38],
#        [30],
#        [36],
#        [36],
#        [ 9],
#        [ 9],
#        [30],
#        [30],
#        [30],
#        [ 6],
#        [ 3],
#        [ 6],
#        [ 6],
#        [24],
#        [12],
#        [12],
#        [24],
#        [12],
#        [24],
#        [24],
#        [24],
#        [ 9],
#        [12],
#        [ 0],
#        [ 0],
#        [24],
#        [30],
#        [36],
#        [ 0],
#        [ 1],
#        [ 3],
#        [ 6],
#        [ 9],
#        [12],
#        [18],
#        [24],
#        [30],
#        [36],
#        [ 0],
#        [30],
#        [18],
#        [32],
#        [32],
#        [ 9],
#        [12],
#        [ 4],
#        [ 0],
#        [ 1],
#        [ 3],
#        [ 6],
#        [ 9],
#        [12],
#        [18],
#        [24],
#        [30],
#        [36],
#        [ 0],
#        [ 1],
#        [ 3],
#        [ 6],
#        [ 9],
#        [12],
#        [18],
#        [ 3],
#        [ 6],
#        [ 9],
#        [ 3],
#        [ 0],
#        [ 3],
#        [ 0],
#        [ 0],
#        [ 3],
#        [ 6],
#        [ 9],
#        [12],
#        [18],
#        [ 0],
#        [ 3],
#        [ 6],
#        [ 9],
#        [ 0],
#        [ 3],
#        [ 6],
#        [ 9],
#        [12],
#        [18],
#        [24],
#        [24],
#        [24],
#        [12],
#        [ 0],
#        [ 6],
#        [12],
#        [ 0],
#        [ 3],
#        [ 6],
#        [ 6],
#        [ 9],
#        [12],
#        [18],
#        [ 0],
#        [ 3],
#        [24],
#        [24],
#        [ 3],
#        [ 9],
#        [12],
#        [18],
#        [ 0],
#        [ 3],
#        [ 6],
#        [36],
#        [ 9],
#        [12],
#        [18],
#        [18],
#        [18],
#        [ 9],
#        [12],
#        [ 3],
#        [36],
#        [36],
#        [13],
#        [ 0],
#        [ 3],
#        [ 6],
#        [ 9],
#        [12],
#        [18],
#        [24],
#        [30],
#        [36],
#        [36],
#        [18],
#        [ 0],
#        [ 0],
#        [ 0],
#        [ 3],
#        [ 6],
#        [ 9],
#        [12],
#        [ 0],
#        [ 9],
#        [12],
#        [18],
#        [ 0],
#        [ 3],
#        [ 6],
#        [ 9],
#        [12],
#        [18],
#        [24],
#        [ 0],
#        [ 3],
#        [ 6],
#        [ 9],
#        [12],
#        [18],
#        [24],
#        [30],
#        [18],
#        [18],
#        [30],
#        [ 4],
#        [31],
#        [34],
#        [37],
#        [36],
#        [36],
#        [ 6],
#        [24],
#        [ 3],
#        [ 3],
#        [ 4],
#        [ 0],
#        [ 0],
#        [ 0],
#        [ 6],
#        [ 6],
#        [ 0],
#        [ 9],
#        [ 9],
#        [ 6],
#        [ 0],
#        [ 3],
#        [ 6],
#        [ 9],
#        [12],
#        [18],
#        [12],
#        [36],
#        [36],
#        [18],
#        [24],
#        [18],
#        [30]], dtype=int64)

# %%
# Plot the data

plt.scatter(X, y)

# %%
# Use sklearn's `train_test_split` to split the data into training and testing

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create the model and fit the model to the data

from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
# Fit the model to train the data. 
# Note: This is the training step where you fit the line to the data.

model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Print the coefficient and the intercept for the model

print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[0.05877234]]
# y-axis intercept:  [3.24439244]

# %%
# Note: we have to transform our min and max values 
# so they are in the format: array([[ 1.17]])
# This is the required format for `model.predict()`

x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[0]]
# Max X Value: [[38]]

# %%
# Calculate the y_min and y_max using model.predict and x_min and x_max

y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
# Plot X and y using plt.scatter
# Plot the model fit line using [x_min[0], x_max[0]], [y_min[0], y_max[0]]

plt.scatter(X, y, c='blue')

plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
plt.xlabel('Time in months', fontsize='large')
plt.ylabel('Impurity', fontsize='large');

# Save Figure
plt.savefig("images/linear.png")

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Use our model to predict a value
predicted = model.predict(X)

# Score the prediction with mse and r2
mse = mean_squared_error(y, predicted)
r2 = r2_score(y, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 0.68379906949429
# R-squared (R2 ): 0.42038274935089837

# %%
# Overall Score for the model
model.score(X, y)
# Out:
# 0.4203827493508984
